# %% [markdown]
# ## Tarefa ref. Aulas 6 a 8 - leitura e gravação de dados

# %%
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
URL = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

r = requests.get(URL)

data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 11961, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001569/2009-81', 'data_protocolo': '2009-12-04T02:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'PEF - Programa Emergencial de Financiamento dos Estados/DF 2', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 91662000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '09/12/2009'}, {'id_pleito': 5933, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000237/2012-85', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infra
# ...

# %%
base_rio = pd.DataFrame(data_json['items'])
base_rio
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0       11961           Estado  Rio de Janeiro        33  RJ
# 1        5933           Estado  Rio de Janeiro        33  RJ
# 2       10849           Estado  Rio de Janeiro        33  RJ
# 3        7085           Estado  Rio de Janeiro        33  RJ
# 4        5516           Estado  Rio de Janeiro        33  RJ
# 5       13624           Estado  Rio de Janeiro        33  RJ
# 6       13271           Estado  Rio de Janeiro        33  RJ
# 7        5918           Estado  Rio de Janeiro        33  RJ
# 8        6833           Estado  Rio de Janeiro        33  RJ
# 9       13364           Estado  Rio de Janeiro        33  RJ
# 10      12375           Estado  Rio de Janeiro        33  RJ
# 11       9102           Estado  Rio de Janeiro        33  RJ
# 12      10562           Estado  Rio de Janeiro        33  RJ
# 13      13629           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 2) Seu código aqui
status_base = list(base_rio['status'].unique())
status_base
# Out:
# ['Encaminhado à PGFN com manifestação técnica favorável',
#  'Deferido',
#  'Arquivado a pedido',
#  'Arquivado por decurso de prazo']

# %%
status_list = list(base_rio['status'].copy())
status_list

for st in status_base:
    status = status_list.count(st)
    print(f'O status {st} ocorre \033[1m{status}\033[0m vezes.')
# Out:
# O status Encaminhado à PGFN com manifestação técnica favorável ocorre 34 vezes.
# O status Deferido ocorre 14 vezes.
# O status Arquivado a pedido ocorre 3 vezes.
# O status Arquivado por decurso de prazo ocorre 1 vezes.

# %%
# 3) Seu código aqui
status_list2 = base_rio[['status', 'data_status']].copy()
status_list2.head()
# Out:
#                                               status data_status
# 0  Encaminhado à PGFN com manifestação técnica fa...  09/12/2009
# 1  Encaminhado à PGFN com manifestação técnica fa...  10/07/2012
# 2  Encaminhado à PGFN com manifestação técnica fa...  01/04/2013
# 3  Encaminhado à PGFN com manifestação técnica fa...  04/10/2012
# 4  Encaminhado à PGFN com manifestação técnica fa...  04/07/2011

# %%
status_list2['ano'] = (status_list2['data_status'].str).split('/').str[2]

status_list2.head()
# Out:
#                                               status data_status   ano
# 0  Encaminhado à PGFN com manifestação técnica fa...  09/12/2009  2009
# 1  Encaminhado à PGFN com manifestação técnica fa...  10/07/2012  2012
# 2  Encaminhado à PGFN com manifestação técnica fa...  01/04/2013  2013
# 3  Encaminhado à PGFN com manifestação técnica fa...  04/10/2012  2012
# 4  Encaminhado à PGFN com manifestação técnica fa...  04/07/2011  2011

# %%
# 4) frequência dos anos
anos = list(status_list2['ano'].unique())
anos
# Out:
# ['2009',
#  '2012',
#  '2013',
#  '2011',
#  '2002',
#  '2016',
#  '2008',
#  '2010',
#  '2006',
#  '2014']

# %%
coluna_ano = list(status_list2['ano'].copy())

for ano in anos:
    cont_ano = coluna_ano.count(ano)
    print(f'O ano {ano} ocorre \033[1m{cont_ano}\033[0m vezes.')
# Out:
# O ano 2009 ocorre 9 vezes.
# O ano 2012 ocorre 11 vezes.
# O ano 2013 ocorre 7 vezes.
# O ano 2011 ocorre 6 vezes.
# O ano 2002 ocorre 4 vezes.
# O ano 2016 ocorre 4 vezes.
# O ano 2008 ocorre 2 vezes.
# O ano 2010 ocorre 3 vezes.
# O ano 2006 ocorre 2 vezes.
# O ano 2014 ocorre 4 vezes.

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
# URL's - Tentei gerar uma basee completa, mas o site trata. Assim, gerei de alguns estados.

URL_sp = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=SP&tipo_interessado=Estado'
URL_rj = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
URL_mg = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'
URL_ba = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
URL_rn = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RN&tipo_interessado=Estado'

# %%
# bases para consolidação da base única

base_sp = requests.get(URL_sp).json()
base_rj = requests.get(URL_rj).json()
base_mg = requests.get(URL_mg).json()
base_ba = requests.get(URL_ba).json()
base_rn = requests.get(URL_rn).json()

# %%
df_sp = pd.DataFrame(base_sp['items'])
df_rj = pd.DataFrame(base_rj['items'])
df_mg = pd.DataFrame(base_mg['items'])
df_ba = pd.DataFrame(base_ba['items'])
df_rn = pd.DataFrame(base_rn['items'])

# %%
# base única

df_full = pd.concat([df_sp, df_rj, df_mg, df_ba, df_rn])

# %%
df_full.shape[0]
# Out:
# 292

# %%
#1) Seu código aqui

def consulta_uf (uf):
    
    df_resumo = df_full.loc[df_full['uf'] == uf]
    
    return df_resumo
   
uf = input('Qual o Estado que deseja consultar? [SP | RJ | MG | BA | RN]: ')

df_resumo = consulta_uf(uf)

df_resumo
# Out:
# Qual o Estado que deseja consultar? [SP | RJ | MG | BA | RN]: BA
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0        6334           Estado       Bahia        29  BA
# 1       22572           Estado       Bahia        29  BA
# 2       18372           Estado       Bahia        29  BA
# 3       18527           Estado       Bahia        29  BA
# 4       45396           Estado       Bahia        29  BA
# ..        ...              ...         ...       ...  ..
# 76      18519           Estado       Bahia        29  BA
# 77       8535           Estado       Bahia        29  BA
# 78      18539           Estado       Bahia        29  BA
# 79      10855           Estado       Bahia        29  BA
# 80      10860           Estado       Bahia        29  BA
#
#                  num_pvl                                             status  \
# 0                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...

# %%
df_full.head(3)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0       7053           Estado   São Paulo        35  SP    None
# 1       7118           Estado   São Paulo        35  SP    None
# 2       6536           Estado   São Paulo        35  SP    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000486/2013-51
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000501/2013-61
# 2                                           Deferido  17944.000375/2012-64
#
#          data_protocolo                                      tipo_operacao  \
# 0  2014-01-31T02:00:00Z  Operação contratual externa (com garantia da U...
# 1  2014-01-23T02:00:00Z  Operação contratual externa (com garantia da U...
# 2  2012-03-16T03:00:00Z                        Operação contratual interna
#
#        finalidade                           tipo_credor  \
# ...

# %%
# 2) Seu código aqui
cond = (df_full['uf'] == 'MG') & (df_full['status'] == 'Arquivado por decurso de prazo')
cond
df_full[cond]['uf'].value_counts()
# Out:
# MG    1
# Name: uf, dtype: int64

# %%
# 3) Seu código aqui
# OBS: Não sei se peguei a base de dados errada, mas não encontrei uma coluna para 'munício' nesse dataframe.
# Fiz a contagem para o Estado.

cond = (df_full['uf'] == 'BA') & (df_full['status'] == 'Deferido')
cond
df_full[cond]['uf'].value_counts()
# Out:
# BA    49
# Name: uf, dtype: int64

# %%
# 4) Seu código aqui
df_ba.to_csv('./base_ba.csv')
